# %%
import pandas as pd

# %%
df= pd.read_csv("retail_store_sales.csv")

# %%
df["Date_raw"] = df["Transaction Date"]

df["Date"] = pd.to_datetime(df["Date_raw"], errors="coerce", dayfirst=True)

mask = df["Date"].isna()
df.loc[mask, "Date"] = pd.to_datetime(df.loc[mask, "Date_raw"], errors="coerce")

df["Date"] = df["Date"].dt.strftime("%d-%m-%Y")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  str
#  1   Customer ID       12575 non-null  str
#  2   Category          12575 non-null  str
#  3   Item              11362 non-null  str
#  4   Price Per Unit    11966 non-null  float64
#  5   Quantity          11971 non-null  float64
#  6   Total Spent       11971 non-null  float64
#  7   Payment Method    12575 non-null  str
#  8   Location          12575 non-null  str
#  9   Transaction Date  12575 non-null  str
#  10  Discount Applied  8376 non-null   object
#  11  Date_raw          12575 non-null  str
#  12  Date              12575 non-null  str
# dtypes: float64(3), object(1), str(9)
# memory usage: 1.2+ MB

# %%
df = df.drop("Transaction Date", axis=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  str
#  1   Customer ID       12575 non-null  str
#  2   Category          12575 non-null  str
#  3   Item              11362 non-null  str
#  4   Price Per Unit    11966 non-null  float64
#  5   Quantity          11971 non-null  float64
#  6   Total Spent       11971 non-null  float64
#  7   Payment Method    12575 non-null  str
#  8   Location          12575 non-null  str
#  9   Discount Applied  8376 non-null   object
#  10  Date_raw          12575 non-null  str
#  11  Date              12575 non-null  str
# dtypes: float64(3), object(1), str(8)
# memory usage: 1.2+ MB

# %%
df = df.drop("Date_raw", axis=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  str
#  1   Customer ID       12575 non-null  str
#  2   Category          12575 non-null  str
#  3   Item              11362 non-null  str
#  4   Price Per Unit    11966 non-null  float64
#  5   Quantity          11971 non-null  float64
#  6   Total Spent       11971 non-null  float64
#  7   Payment Method    12575 non-null  str
#  8   Location          12575 non-null  str
#  9   Discount Applied  8376 non-null   object
#  10  Date              12575 non-null  str
# dtypes: float64(3), object(1), str(7)
# memory usage: 1.1+ MB

# %%
df["Date"] = pd.to_datetime(df["Date"], errors="coerce", dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  str
#  1   Customer ID       12575 non-null  str
#  2   Category          12575 non-null  str
#  3   Item              11362 non-null  str
#  4   Price Per Unit    11966 non-null  float64
#  5   Quantity          11971 non-null  float64
#  6   Total Spent       11971 non-null  float64
#  7   Payment Method    12575 non-null  str
#  8   Location          12575 non-null  str
#  9   Discount Applied  8376 non-null   object
#  10  Date              12575 non-null  datetime64[us]
# dtypes: datetime64[us](1), float64(3), object(1), str(6)
# memory usage: 1.1+ MB

# %%
df["Day_Name"] = df["Date"].dt.day_name()
df["Month"] = df["Date"].dt.month_name()

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Discount Applied       Date  \
# 0      10.0        185.0  Digital Wallet   Online             True 2024-08-04
# 1       9.0        261.0  Digital Wallet   Online             True 2023-07-23
# 2       2.0         43.0     Credit Card   Online            False 2022-05-10
# 3       9.0        247.5     Credit Card   Online              NaN 2022-07-05
# 4       7.0         87.5  Digital Wallet   Online            False 2022-02-10
#
#    Day_Name     Month
# 0    Sunday    August
# 1    Sunday      July
# 2   Tuesday       May
# 3   Tuesday      July
# 4  Thursday  February

# %%
months = ["", "January", "February", "March", "April",
    "May", "June", "July", "August",
    "September", "October", "November", "December"]

# %%
df["Monthaa"] = df["Date"].dt.month_name()

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Discount Applied       Date  \
# 0      10.0        185.0  Digital Wallet   Online             True 2024-08-04
# 1       9.0        261.0  Digital Wallet   Online             True 2023-07-23
# 2       2.0         43.0     Credit Card   Online            False 2022-05-10
# 3       9.0        247.5     Credit Card   Online              NaN 2022-07-05
# 4       7.0         87.5  Digital Wallet   Online            False 2022-02-10
#
#    Day_Name     Month   Monthaa
# 0    Sunday    August    August
# 1    Sunday      July      July
# 2   Tuesday       May       May
# 3   Tuesday      July      July
# 4  Thursday  February  February

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  str
#  1   Customer ID       12575 non-null  str
#  2   Category          12575 non-null  str
#  3   Item              11362 non-null  str
#  4   Price Per Unit    11966 non-null  float64
#  5   Quantity          11971 non-null  float64
#  6   Total Spent       11971 non-null  float64
#  7   Payment Method    12575 non-null  str
#  8   Location          12575 non-null  str
#  9   Discount Applied  8376 non-null   object
#  10  Date              12575 non-null  datetime64[us]
#  11  Day_Name          12575 non-null  str
#  12  Month             12575 non-null  str
# dtypes: datetime64[us](1), float64(3), object(1), str(8)
# memory usage: 1.2+ MB
